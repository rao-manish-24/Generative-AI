# %% [markdown]
# ### Imports and Settings

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import pandas_datareader.data as web
from scipy.stats import spearmanr

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import Sequential
from keras.layers import Dense, LSTM
from tensorflow.keras.layers import Dense, LSTM
from tensorflow import keras

import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime
import yfinance as yf

# %% [markdown]
# ### Model Input

# %%
# set up the random state
sns.set_style('whitegrid')
np.random.seed(42)

start_date = datetime(2020,1,1)
end_date = datetime(2024,8,31)
stock_symbol = 'AAPL'

# Download stock data from yahoo finance
stocks = yf.download('AAPL',start_date ,end_date)
price_type = 'Adj Close'
stock_price = pd.DataFrame(stocks[price_type])
# print(stock_price)

ax = stock_price.plot(title = stock_symbol, legend=False, linewidth = 2, figsize=(14, 4), rot=0)
ax.set_xlabel('')
sns.despine()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
scaler = MinMaxScaler()
stocks_scaled = pd.Series(scaler.fit_transform(stock_price.values.reshape(-1, 1)).squeeze(), 
                         index = stock_price.index)
# print(stocks_scaled)

# %% [markdown]
# ### Model Processing

# %%
def create_univariate_lstm_data(data, window_size):
    n = len(data) 
    y = data[window_size:]
    # print(data)
    data = data.values.reshape(-1, 1) # make 2D
    # print(data)
    X = np.hstack(tuple([data[i: n-j, :] for i, j in enumerate(range(window_size, 0, -1))]))
    return pd.DataFrame(X, index=y.index), y

window_size = 60
X, y = create_univariate_lstm_data(stocks_scaled, window_size = window_size)

# Train-test split
X_train = X[:'2022'].values.reshape(-1, window_size, 1)
# print(X_train)
y_train = y[:'2022']
y_train.shape

n_obs, window_size, n_features = X_train.shape 
# keep the last year for testing
X_test = X['2023':].values.reshape(-1, window_size, 1)
# print(X_test)
y_test = y['2023':]

# %%
X_train.shape
# Out:
# (696, 60, 1)

# %%
def create_LSTM(hidden_units, dense_units, input_shape, activation):
    model = Sequential() # clarify hidden states vs hidden layers
    model.add(LSTM(hidden_units, input_shape = input_shape, activation=activation[0]))
    model.add(Dense(units=dense_units, activation=activation[1]))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# Create model and train
lstm = create_LSTM(hidden_units = 50, dense_units = 1, input_shape = (window_size, n_features), 
                   activation=['tanh', 'linear'])
lstm.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 50)             │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,451 (40.82 KB)
#  Trainable params: 10,451 (40.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
LSTM_training = lstm.fit(X_train, 
                       y_train, 
                       epochs = 128, 
                       batch_size = 20,
                       validation_data = (X_test, y_test),
                       verbose=1)
# Out:
# Epoch 1/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 0.0629 - val_loss: 0.0085
# Epoch 2/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 3/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 4/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 9.3112e-04 - val_loss: 0.0016
# Epoch 5/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 7.2771e-04 - val_loss: 8.5345e-04
# Epoch 6/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 8.1004e-04 - val_loss: 8.5665e-04
# Epoch 7/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 7.5591e-04 - val_loss: 7.8765e-04
# Epoch 8/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 7.3146e-04 - val_loss: 0.0010
# Epoch 9/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 8.6931e-04 - val_loss: 7.5496e-04
# Epoch 10/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.8261e-04 - val_loss: 8.7730e-04
# Epoch 11/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 7.0440e-04 - val_loss: 8.5819e-04
# Epoch 12/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 6.2881e-04 - val_loss: 7.0767e-04
# Epoch 13/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 6.9407e-04 - val_loss: 7.6522e-04
# Epoch 14/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 6.5042e-04 - val_loss: 7.7274e-04
# Epoch 15/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 7.0614e-04 - val_loss: 8.6877e-04
# Epoch 16/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.3510e-04 - val_loss: 7.3194e-04
# Epoch 17/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 6.6843e-04 - val_loss: 6.7341e-04
# Epoch 18/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 5.9190e-04 - val_loss: 7.0333e-04
# Epoch 19/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 6.2089e-04 - val_loss: 6.8787e-04
# Epoch 20/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 5.9274e-04 - val_loss: 7.9406e-04
# Epoch 21/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 6.0287e-04 - val_loss: 5.7684e-04
# Epoch 22/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 5.9600e-04 - val_loss: 0.0010
# Epoch 23/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 6.2145e-04 - val_loss: 9.2865e-04
# Epoch 24/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 6.5608e-04 - val_loss: 5.7541e-04
# Epoch 25/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 5.2655e-04 - val_loss: 0.0010
# Epoch 26/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.4934e-04 - val_loss: 6.6712e-04
# Epoch 27/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 5.1106e-04 - val_loss: 5.4203e-04
# Epoch 28/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 5.1513e-04 - val_loss: 7.7895e-04
# Epoch 29/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 5.1561e-04 - val_loss: 7.8338e-04
# Epoch 30/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 4.9704e-04 - val_loss: 9.5587e-04
# Epoch 31/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 5.1897e-04 - val_loss: 5.8030e-04
# Epoch 32/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 5.0531e-04 - val_loss: 4.7075e-04
# Epoch 33/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 5.1577e-04 - val_loss: 6.6892e-04
# Epoch 34/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 4.6813e-04 - val_loss: 4.9641e-04
# Epoch 35/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 4.7233e-04 - val_loss: 8.2618e-04
# Epoch 36/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 5.1810e-04 - val_loss: 4.4548e-04
# Epoch 37/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 4.7186e-04 - val_loss: 7.8239e-04
# Epoch 38/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 4.9932e-04 - val_loss: 7.3632e-04
# Epoch 39/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 4.4593e-04 - val_loss: 7.2505e-04
# Epoch 40/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 4.5235e-04 - val_loss: 8.2650e-04
# Epoch 41/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 4.2556e-04 - val_loss: 5.8868e-04
# Epoch 42/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 4.2425e-04 - val_loss: 4.1160e-04
# Epoch 43/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 4.8376e-04 - val_loss: 4.7170e-04
# Epoch 44/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 4.1035e-04 - val_loss: 5.7174e-04
# Epoch 45/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 5.0502e-04 - val_loss: 3.9797e-04
# Epoch 46/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 4.2661e-04 - val_loss: 5.5762e-04
# Epoch 47/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 4.3837e-04 - val_loss: 3.9052e-04
# Epoch 48/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 3.8830e-04 - val_loss: 4.9247e-04
# Epoch 49/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 4.2596e-04 - val_loss: 9.7888e-04
# Epoch 50/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 4.1740e-04 - val_loss: 4.2918e-04
# Epoch 51/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 4.4272e-04 - val_loss: 3.7264e-04
# Epoch 52/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.3115e-04 - val_loss: 7.3839e-04
# Epoch 53/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 4.1450e-04 - val_loss: 7.5520e-04
# Epoch 54/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 3.6355e-04 - val_loss: 5.4110e-04
# Epoch 55/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.9418e-04 - val_loss: 3.9096e-04
# Epoch 56/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.8700e-04 - val_loss: 3.7520e-04
# Epoch 57/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 3.9906e-04 - val_loss: 6.4850e-04
# Epoch 58/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.0291e-04 - val_loss: 5.9703e-04
# Epoch 59/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 4.2743e-04 - val_loss: 6.9980e-04
# Epoch 60/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 3.6386e-04 - val_loss: 3.6445e-04
# Epoch 61/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 3.5293e-04 - val_loss: 4.5602e-04
# Epoch 62/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 3.6337e-04 - val_loss: 6.0431e-04
# Epoch 63/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 3
128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 3.5872e-04 - val_loss: 2.3356e-04
# Epoch 111/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 2.8972e-04 - val_loss: 4.9305e-04
# Epoch 112/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 2.9041e-04 - val_loss: 2.3076e-04
# Epoch 113/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.7163e-04 - val_loss: 3.5553e-04
# Epoch 114/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 3.1248e-04 - val_loss: 2.2706e-04
# Epoch 115/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 2.9236e-04 - val_loss: 3.2461e-04
# Epoch 116/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 2.6630e-04 - val_loss: 2.3459e-04
# Epoch 117/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 2.5085e-04 - val_loss: 2.6038e-04
# Epoch 118/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 2.7644e-04 - val_loss: 4.0428e-04
# Epoch 119/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 2.6225e-04 - val_loss: 2.5305e-04
# Epoch 120/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 2.7829e-04 - val_loss: 2.6666e-04
# Epoch 121/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 2.6776e-04 - val_loss: 2.1718e-04
# Epoch 122/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 2.8924e-04 - val_loss: 2.1953e-04
# Epoch 123/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 3.1095e-04 - val_loss: 2.3411e-04
# Epoch 124/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 2.6159e-04 - val_loss: 3.4521e-04
# Epoch 125/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 2.7376e-04 - val_loss: 7.1998e-04
# Epoch 126/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 2.6268e-04 - val_loss: 3.6323e-04
# Epoch 127/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 2.5608e-04 - val_loss: 2.8338e-04
# Epoch 128/128
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 2.6547e-04 - val_loss: 2.8695e-04

# %% [markdown]
# ### Model Output

# %%
fig, ax = plt.subplots(figsize=(12, 4))

loss_history = pd.DataFrame(LSTM_training.history).pow(.5)
loss_history.index += 1
best_rmse = loss_history.val_loss.min()

best_epoch = loss_history.val_loss.idxmin()

title = f'5-Epoch Rolling RMSE (Best Validation RMSE: {best_rmse:.4%})'
loss_history.columns=['Training RMSE', 'Validation RMSE']
loss_history.rolling(5).mean().plot(logy=True, lw=2, title=title, ax=ax)

ax.axvline(best_epoch, ls='--', lw=1, c='k')

sns.despine()
fig.tight_layout()

# %%
train_rmse_scaled = np.sqrt(lstm.evaluate(X_train, y_train, verbose=0))
test_rmse_scaled = np.sqrt(lstm.evaluate(X_test, y_test, verbose=0))
print(f'Train RMSE (scaled): {train_rmse_scaled:.4f} | Test RMSE (scaled): {test_rmse_scaled:.4f}')
# Out:
# Train RMSE (scaled): 0.0302 | Test RMSE (scaled): 0.0268

# %%
train_predict_scaled = lstm.predict(X_train)
test_predict_scaled = lstm.predict(X_test)

train_ic = spearmanr(y_train, train_predict_scaled)[0]
test_ic = spearmanr(y_test, test_predict_scaled)[0]
print(f"Train IC: {train_ic:.4f} | Test IC: {test_ic:.4f}")
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Train IC: 0.9823 | Test IC: 0.9926

# %% [markdown]
# **Rescale Predictions**

# %%
train_predict = pd.Series(scaler.inverse_transform(train_predict_scaled).squeeze(), index=y_train.index)
test_predict = (pd.Series(scaler.inverse_transform(test_predict_scaled).squeeze(), index=y_test.index))
# use inverse_transform to convert the scaled data back to its original scale.
y_train_rescaled = scaler.inverse_transform(y_train.to_frame()).squeeze()
y_test_rescaled = scaler.inverse_transform(y_test.to_frame()).squeeze()

# %%
train_rmse = np.sqrt(mean_squared_error(train_predict, y_train_rescaled))
test_rmse = np.sqrt(mean_squared_error(test_predict, y_test_rescaled))
print(f"Train RMSE: {train_rmse:.2f} | Test RMSE: {test_rmse:.2f}")
# Out:
# Train RMSE: 3.57 | Test RMSE: 3.16

# %%
stock_price['Train Predictions'] = train_predict
stock_price['Test Predictions'] = test_predict

to_be_merged = pd.concat([train_predict.to_frame('predictions').assign(data='Train'), 
                   test_predict.to_frame('predictions').assign(data='Test')])

stock_price = pd.merge(stock_price, to_be_merged, how='inner', on = 'Date')
# remove the suffixes brought by pd.merge()
stock_price.columns = stock_price.columns.str.rstrip('_x').str.rstrip('_y')

# %% [markdown]
# ### Visualization

# %%
stock_price
# Out:
#              Adj Close  Train Predictions  Test Predictions  predictions  \
# Date
# 2020-03-30   98.197502          94.984619               NaN    94.984619
# 2020-03-31   97.486000          96.712341               NaN    96.712341
# 2020-04-01   95.385002          96.934547               NaN    96.934547
# 2020-04-02   95.941498          95.462410               NaN    95.462410
# 2020-04-03   95.329498          95.299973               NaN    95.299973
# ...                ...                ...               ...          ...
# 2024-08-26  175.500000                NaN        174.895081   174.895081
# 2024-08-27  173.119995                NaN        173.970367   173.970367
# 2024-08-28  170.800003                NaN        171.558456   171.558456
# 2024-08-29  172.119995                NaN        169.132019   169.132019
# 2024-08-30  178.500000                NaN        170.261108   170.261108
#
#              data
# Date
# 2020-03-30  Train
# 2020-03-31  Train
# 2020-04-01  Train
# 2020-04-02  Train
# 2020-04-03  Train
# ...           ...
# 2024-08-26   Test
# 2024-08-27   Test
# 2024-08-28   Test
# 2024-08-29   Test
# 2024-08-30   Test
#
# [1114 rows x 5 columns]

# %%
fig=plt.figure(figsize=(14,7))
ax1 = plt.subplot(221)
stock_price.loc['2020':, price_type].plot(lw=2, ax=ax1, c='k')
stock_price.loc['2020':, ['Test Predictions', 'Train Predictions']].plot(lw=1, ax=ax1, ls='--')
ax1.set_title('In- and Out-of-sample Predictions')

with sns.axes_style("white"):
    ax3 = plt.subplot(223)
    sns.scatterplot(x = price_type, y = 'predictions', data = stock_price, hue = 'data', ax = ax3)
    ax3.text(x=.02, y=.95, s=f'Test IC ={test_ic:.2%}', transform=ax3.transAxes)
    ax3.text(x=.02, y=.87, s=f'Train IC={train_ic:.2%}', transform=ax3.transAxes)
    ax3.set_title('Correlation')
    ax3.legend(loc='lower right')
    
    ax2 = plt.subplot(222)
    ax4 = plt.subplot(224, sharex = ax2, sharey=ax2)
    sns.distplot(train_predict.squeeze()- y_train_rescaled, ax=ax2)
    ax2.set_title('Train Error')
    ax2.text(x=.03, y=.92, s=f'Train RMSE = ${train_rmse:.4f}', transform=ax2.transAxes)
    sns.distplot(test_predict.squeeze()-y_test_rescaled, ax=ax4)
    ax4.set_title('Test Error')
    ax4.text(x=.03, y=.92, s=f'Test RMSE = ${test_rmse:.4f}', transform=ax4.transAxes)

sns.despine()
fig.tight_layout()

# %% [markdown]
# **Changes made in the Hyperparamter**
#
# ###### hidden_units = 50
# ###### activation=['tanh', 'linear']
# ###### epochs = 100
# ###### batch_size = 20
# ###### window_size = 60
